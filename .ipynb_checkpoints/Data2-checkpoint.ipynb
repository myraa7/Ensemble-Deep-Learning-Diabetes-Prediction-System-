# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv('Data2/diabetes.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               2000 non-null   int64
#  1   Glucose                   2000 non-null   int64
#  2   BloodPressure             2000 non-null   int64
#  3   SkinThickness             2000 non-null   int64
#  4   Insulin                   2000 non-null   int64
#  5   BMI                       2000 non-null   float64
#  6   DiabetesPedigreeFunction  2000 non-null   float64
#  7   Age                       2000 non-null   int64
#  8   Outcome                   2000 non-null   int64
# dtypes: float64(2), int64(7)
# memory usage: 140.8 KB

# %%
data = data.replace([np.inf, -np.inf], np.nan)

# %%
null_counts = data.isnull().sum()
# Print the number of null values
print(f"{null_counts.sum()} null entries have been found in the dataset\n")
# Drop null values
data.dropna(inplace=True)          # or df_data = df_data.dropna()

# Find and handle duplicates
duplicate_count = data.duplicated().sum()
# Print the number of duplicate entries
print(f"{duplicate_count} duplicate entries have been found in the dataset\n")
# Remove duplicates
data.drop_duplicates(inplace=True)  # or df_data = df_data.drop_duplicates()
# Display relative message
print(f"All duplicates have been removed\n")

# Reset the indexes
data.reset_index(drop=True, inplace=True)

# Inspect the dataset for categorical columns
print("Categorical columns:",data.select_dtypes(include=['object']).columns.tolist(),'\n')

# Print the first 5 lines
data.head()
# Out:
# 0 null entries have been found in the dataset
#
# 1256 duplicate entries have been found in the dataset
#
# All duplicates have been removed
#
# Categorical columns: []
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            2      138             62             35        0  33.6
# 1            0       84             82             31      125  38.2
# 2            0      145              0              0        0  44.2
# 3            0      135             68             42      250  42.3
# 4            1      139             62             41      480  40.7
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.127   47        1
# 1                     0.233   23        0
# 2                     0.630   31        1
# 3                     0.365   24        1
# 4                     0.536   21        0

# %%
data = data.dropna()

# %%
data.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
data['Outcome'].value_counts()
# Out:
# 0    491
# 1    253
# Name: Outcome, dtype: int64

# %%
# Plotting the distribution of the binary target variable y
plt.figure(figsize=(8, 6))
sns.countplot(x=data['Outcome'], palette='Greens')
plt.title('Distribution of Target Variable')
plt.xlabel('Target Class')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize = (10,5))
sns.heatmap(data.corr(), annot = True, cmap="rainbow")
plt.show()

# %%
X = data.drop(["Outcome"],axis =1)
y = data["Outcome"]

# %%
from sklearn.ensemble import ExtraTreesClassifier
import matplotlib.pyplot as plt
model = ExtraTreesClassifier()
model.fit(X,y)
# Out:
# ExtraTreesClassifier()

# %%
#plot graph of feature importances for better visualization
feat_importances = pd.Series(model.feature_importances_, index=X.columns)
feat_importances.nlargest(10).plot(kind='barh')
plt.show()

# %%
data.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
data = data[['Glucose','Age','BMI','DiabetesPedigreeFunction','Pregnancies','BloodPressure', 'SkinThickness', 'Insulin','Outcome' ]]

# %%
data.head()
# Out:
#    Glucose  Age   BMI  DiabetesPedigreeFunction  Pregnancies  BloodPressure  \
# 0      138   47  33.6                     0.127            2             62
# 1       84   23  38.2                     0.233            0             82
# 2      145   31  44.2                     0.630            0              0
# 3      135   24  42.3                     0.365            0             68
# 4      139   21  40.7                     0.536            1             62
#
#    SkinThickness  Insulin  Outcome
# 0             35        0        1
# 1             31      125        0
# 2              0        0        1
# 3             42      250        1
# 4             41      480        0

# %%
X = data.drop(["Outcome"],axis =1)
y = data["Outcome"]

# %%
from imblearn.over_sampling import SMOTE

# %%
ada = SMOTE(random_state=42)
X_res, y_res = ada.fit_resample(X, y)

# %%
from sklearn.metrics import accuracy_score # for calculating accuracy of model
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import roc_auc_score

# %%
ML_Model = []
accuracy = []
precision = []
recall = []
f1score = []

#function to call for storing the results
def storeResults(model, a,b,c,d):
    ML_Model.append(model)
    accuracy.append(round(a, 3))
    precision.append(round(b, 3))
    recall.append(round(c, 3))
    f1score.append(round(d, 3))

# %%
from tensorflow import keras
callback = keras.callbacks.EarlyStopping(monitor='val_accuracy',patience=5)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_res, y_res, test_size=0.4, random_state=42)

# %% [markdown]
# # LSTM

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout, LSTM, SimpleRNN, Bidirectional, GRU
from tensorflow.keras.optimizers import RMSprop

# %%
# Scale the features using StandardScaler
from sklearn.preprocessing import StandardScaler, MinMaxScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
X_test = X_test.reshape((X_test.shape[0], 1, X_test.shape[1]))

# %%
model5 = Sequential()
model5.add(LSTM(50, input_shape=(X_train.shape[1], X_train.shape[2])))
model5.add(Dropout(0.5))
model5.add(Dense(1, activation='sigmoid'))

learning_rate = 0.001
optimizer = RMSprop(learning_rate=learning_rate)
model5.compile(optimizer=optimizer,loss='binary_crossentropy', metrics=['accuracy'])

# %%
history5 = model5.fit(X_train, y_train, batch_size=2, validation_split=0.34,shuffle=True,epochs=30,verbose=1,callbacks=[callback])
# Out:
# Epoch 1/30
# 194/194 [==============================] - 5s 8ms/step - loss: 0.6372 - accuracy: 0.7165 - val_loss: 0.5964 - val_accuracy: 0.7363
# Epoch 2/30
# 194/194 [==============================] - 1s 6ms/step - loss: 0.5766 - accuracy: 0.7268 - val_loss: 0.5432 - val_accuracy: 0.7164
# Epoch 3/30
# 194/194 [==============================] - 1s 6ms/step - loss: 0.5305 - accuracy: 0.7216 - val_loss: 0.5178 - val_accuracy: 0.7164
# Epoch 4/30
# 194/194 [==============================] - 1s 6ms/step - loss: 0.5205 - accuracy: 0.7294 - val_loss: 0.5079 - val_accuracy: 0.7363
# Epoch 5/30
# 194/194 [==============================] - 1s 6ms/step - loss: 0.5148 - accuracy: 0.7242 - val_loss: 0.5018 - val_accuracy: 0.7463
# Epoch 6/30
# 194/194 [==============================] - 1s 6ms/step - loss: 0.4965 - accuracy: 0.7500 - val_loss: 0.4983 - val_accuracy: 0.7463
# Epoch 7/30
# 194/194 [==============================] - 1s 6ms/step - loss: 0.4971 - accuracy: 0.7603 - val_loss: 0.4958 - val_accuracy: 0.7363
# Epoch 8/30
# 194/194 [==============================] - 1s 6ms/step - loss: 0.4955 - accuracy: 0.7603 - val_loss: 0.4943 - val_accuracy: 0.7313
# Epoch 9/30
# 194/194 [==============================] - 1s 6ms/step - loss: 0.4930 - accuracy: 0.7680 - val_loss: 0.4946 - val_accuracy: 0.7313
# Epoch 10/30
# 194/194 [==============================] - 1s 6ms/step - loss: 0.4959 - accuracy: 0.7603 - val_loss: 0.4942 - val_accuracy: 0.7413

# %%
# Plotting akurasi
plt.plot(history5.history['accuracy'], label='Training Accuracy')
plt.plot(history5.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plotting kerugian
plt.plot(history5.history['loss'], label='Training Loss')
plt.plot(history5.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
y_pred_prob = model5.predict(X_test)
y_pred1 = (y_pred_prob > 0.55).astype("int32")

dl_acc = accuracy_score(y_test,y_pred1)
dl_prec = precision_score(y_test,y_pred1)
dl_rec = recall_score(y_test,y_pred1)
dl_f1 = f1_score(y_test,y_pred1)
# Out:
# 13/13 [==============================] - 0s 2ms/step

# %%
storeResults('LSTM',dl_acc,dl_prec,dl_rec,dl_f1)

# %% [markdown]
# # ANN

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping

# %%
X_train, X_test, y_train, y_test = train_test_split(X_res, y_res, test_size=0.4, random_state=42)
# Scale the features using StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
# Build the model architecture
model = tf.keras.Sequential([
    tf.keras.layers.Dense(1024, activation='relu', input_dim=X_train.shape[1]),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(128, activation='tanh'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# Compile the model
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(X_train, y_train, epochs=30, batch_size=2, validation_split=0.2)
# Out:
# Epoch 1/30
# 236/236 [==============================] - 3s 7ms/step - loss: 0.8987 - accuracy: 0.5902 - val_loss: 0.5419 - val_accuracy: 0.7119
# Epoch 2/30
# 236/236 [==============================] - 2s 6ms/step - loss: 0.7609 - accuracy: 0.6327 - val_loss: 0.6073 - val_accuracy: 0.6610
# Epoch 3/30
# 236/236 [==============================] - 2s 7ms/step - loss: 0.7732 - accuracy: 0.6030 - val_loss: 0.5761 - val_accuracy: 0.6949
# Epoch 4/30
# 236/236 [==============================] - 2s 7ms/step - loss: 0.7848 - accuracy: 0.6115 - val_loss: 0.5513 - val_accuracy: 0.7203
# Epoch 5/30
# 236/236 [==============================] - 2s 7ms/step - loss: 0.7076 - accuracy: 0.5945 - val_loss: 0.5714 - val_accuracy: 0.7203
# Epoch 6/30
# 236/236 [==============================] - 2s 7ms/step - loss: 0.6957 - accuracy: 0.6327 - val_loss: 0.5142 - val_accuracy: 0.7119
# Epoch 7/30
# 236/236 [==============================] - 2s 7ms/step - loss: 0.7110 - accuracy: 0.5945 - val_loss: 0.5506 - val_accuracy: 0.7119
# Epoch 8/30
# 236/236 [==============================] - 2s 7ms/step - loss: 0.6714 - accuracy: 0.6285 - val_loss: 0.4948 - val_accuracy: 0.6949
# Epoch 9/30
# 236/236 [==============================] - 2s 7ms/step - loss: 0.6626 - accuracy: 0.6391 - val_loss: 0.4836 - val_accuracy: 0.7458
# Epoch 10/30
# 236/236 [==============================] - 2s 7ms/step - loss: 0.6415 - accuracy: 0.6603 - val_loss: 0.4795 - val_accuracy: 0.7542
# Epoch 11/30
# 236/236 [==============================] - 2s 7ms/step - loss: 0.6256 - accuracy: 0.6539 - val_loss: 0.5372 - val_accuracy: 0.7203
# Epoch 12/30
# 236/236 [==============================] - 2s 7ms/step - loss: 0.6463 - accuracy: 0.6285 - val_loss: 0.5220 - val_accuracy: 0.7119
# Epoch 13/30
# 236/236 [==============================] - 2s 7ms/step - loss: 0.6519 - accuracy: 0.6306 - val_loss: 0.5498 - val_accuracy: 0.7034
# Epoch 14/30
# 236/236 [==============================] - 2s 7ms/step - loss: 0.6496 - accuracy: 0.6200 - val_loss: 0.4998 - val_accuracy: 0.7203
# Epoch 15/30
# 236/236 [==============================] - 2s 7ms/step - loss: 0.6505 - accuracy: 0.6476 - val_loss: 0.5466 - val_accuracy: 0.7119
# Epoch 16/30
# 236/236 [==============================] - 2s 7ms/step - loss: 0.6496 - accuracy: 0.6476 - val_loss: 0.5224 - val_accuracy: 0.7542
# Epoch 17/30
# 236/236 [==============================] - 2s 7ms/step - loss: 0.6397 - accuracy: 0.6157 - val_loss: 0.5448 - val_accuracy: 0.6864
# Epoch 18/30
# 236/236 [==============================] - 2s 7ms/step - loss: 0.6494 - accuracy: 0.6327 - val_loss: 0.5706 - val_accuracy: 0.6949
# Epoch 19/30
# 236/236 [==============================] - 2s 7ms/step - loss: 0.6452 - accuracy: 0.6200 - val_loss: 0.5365 - val_accuracy: 0.7288
# Epoch 20/30
# 236/236 [==============================] - 2s 7ms/step - loss: 0.6569 - accuracy: 0.6391 - val_loss: 0.5486 - val_accuracy: 0.7203
# Epoch 21/30
# 236/236 [==============================] - 2s 7ms/step - loss: 0.6333 - accuracy: 0.6900 - val_loss: 0.5244 - val_accuracy: 0.7627
# Epoch 22/30
# 236/236 [==============================] - 2s 7ms/step - loss: 0.6258 - accuracy: 0.6688 - val_loss: 0.4968 - val_accuracy: 0.7542
# Epoch 23/30
# 236/236 [==============================] - 2s 7ms/step - loss: 0.6488 - accuracy: 0.6391 - val_loss: 0.5602 - val_accuracy: 0.7203
# Epoch 24/30
# 236/236 [==============================] - 2s 7ms/step - loss: 0.6150 - accuracy: 0.6667 - val_loss: 0.5220 - val_accuracy: 0.7373
# Epoch 25/30
# 236/236 [==============================] - 2s 6ms/step - loss: 0.6359 - accuracy: 0.6476 - val_loss: 0.5436 - val_accuracy: 0.7288
# Epoch 26/30
# 236/236 [==============================] - 2s 6ms/step - loss: 0.6449 - accuracy: 0.6327 - val_loss: 0.5761 - val_accuracy: 0.7119
# Epoch 27/30
# 236/236 [==============================] - 2s 7ms/step - loss: 0.6332 - accuracy: 0.6263 - val_loss: 0.5276 - val_accuracy: 0.6949
# Epoch 28/30
# 236/236 [==============================] - 2s 6ms/step - loss: 0.6477 - accuracy: 0.6242 - val_loss: 0.5273 - val_accuracy: 0.7288
# Epoch 29/30
# 236/236 [==============================] - 2s 7ms/step - loss: 0.6248 - accuracy: 0.6285 - val_loss: 0.5270 - val_accuracy: 0.7288
# Epoch 30/30
# 236/236 [==============================] - 2s 7ms/step - loss: 0.6144 - accuracy: 0.6688 - val_loss: 0.5167 - val_accuracy: 0.7203

# %%
# Evaluate the model on the testing set
predict_x=model.predict(X_test) 
y_pred2=np.argmax(predict_x,axis=1)
# Out:
# 13/13 [==============================] - 0s 2ms/step

# %%
dl_acc = accuracy_score(y_test,y_pred2)
dl_prec = precision_score(y_test,y_pred2)
dl_rec = recall_score(y_test,y_pred2)
dl_f1 = f1_score(y_test,y_pred2)

storeResults('ANN',dl_acc,dl_prec,dl_rec,dl_f1)

# %% [markdown]
# # CNN

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.callbacks import EarlyStopping

# %%
# Membagi data menjadi set pelatihan dan pengujian
X_train, X_test, y_train, y_test = train_test_split(X_res, y_res, test_size=0.4, random_state=42)

# %%
def build_model(input_shape):
    model = Sequential()
    
    model.add(Conv1D(64, 1, activation='tanh', input_shape=input_shape))
    model.add(MaxPooling1D(1))
    model.add(Dropout(0.1))
    
    model.add(Conv1D(32, 2, activation='tanh'))  # Added another convolutional layer
    model.add(MaxPooling1D(2))  # Increased pooling window size
    model.add(Dropout(0.1))  # Adjusted dropout rate
    
    model.add(Conv1D(16, 2, activation='tanh'))  # Added another convolutional layer
    model.add(MaxPooling1D(1))  # Increased pooling window size
    model.add(Dropout(0.1))  # Adjusted dropout rate
        
    model.add(Flatten())
    model.add(Dense(8, activation='tanh'))
    model.add(Dropout(0.1))
    model.add(Dense(1, activation='sigmoid'))  # Assuming binary classification
    return model

# %%
# Build the model
model1 = build_model((X_train.shape[1], 1))
model1.summary()
# Compile the model (assuming learning rate and optimizer values are chosen)
model1.compile(loss='binary_crossentropy', optimizer='sgd', metrics=['accuracy'])
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 8, 64)             128
#
#  max_pooling1d (MaxPooling1D  (None, 8, 64)            0
#  )
#
#  dropout_4 (Dropout)         (None, 8, 64)             0
#
#  conv1d_1 (Conv1D)           (None, 7, 32)             4128
#
#  max_pooling1d_1 (MaxPooling  (None, 3, 32)            0
#  1D)
#
#  dropout_5 (Dropout)         (None, 3, 32)             0
#
#  conv1d_2 (Conv1D)           (None, 2, 16)             1040
#
#  max_pooling1d_2 (MaxPooling  (None, 2, 16)            0
#  1D)
#
#  dropout_6 (Dropout)         (None, 2, 16)             0
#
#  flatten (Flatten)           (None, 32)                0
#
#  dense_5 (Dense)             (None, 8)                 264
#
#  dropout_7 (Dropout)         (None, 8)                 0
#
#  dense_6 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 5,569
# Trainable params: 5,569
# Non-trainable params: 0
# _________________________________________________________________

# %%
history1 = model1.fit(X_train, y_train, validation_split=0.34,shuffle=True,epochs=30,batch_size=2, verbose=1,callbacks=[callback])
# Out:
# Epoch 1/30
# 194/194 [==============================] - 3s 6ms/step - loss: 0.7374 - accuracy: 0.4897 - val_loss: 0.6909 - val_accuracy: 0.5124
# Epoch 2/30
# 194/194 [==============================] - 1s 5ms/step - loss: 0.7196 - accuracy: 0.5077 - val_loss: 0.6741 - val_accuracy: 0.6169
# Epoch 3/30
# 194/194 [==============================] - 1s 5ms/step - loss: 0.6915 - accuracy: 0.5438 - val_loss: 0.6714 - val_accuracy: 0.5970
# Epoch 4/30
# 194/194 [==============================] - 1s 5ms/step - loss: 0.6784 - accuracy: 0.5928 - val_loss: 0.6738 - val_accuracy: 0.6070
# Epoch 5/30
# 194/194 [==============================] - 1s 5ms/step - loss: 0.6757 - accuracy: 0.5979 - val_loss: 0.6704 - val_accuracy: 0.5821
# Epoch 6/30
# 194/194 [==============================] - 1s 5ms/step - loss: 0.6735 - accuracy: 0.5928 - val_loss: 0.6725 - val_accuracy: 0.6169
# Epoch 7/30
# 194/194 [==============================] - 1s 5ms/step - loss: 0.6743 - accuracy: 0.6108 - val_loss: 0.6726 - val_accuracy: 0.6070

# %%
y_pred_prob = model1.predict(X_test)
y_pred3 = (y_pred_prob > 0.55).astype("int32")

dl_acc = accuracy_score(y_test,y_pred3)
dl_prec = precision_score(y_test,y_pred3)
dl_rec = recall_score(y_test,y_pred3)
dl_f1 = f1_score(y_test,y_pred3)
# Out:
# 13/13 [==============================] - 0s 2ms/step

# %%
storeResults('CNN',dl_acc,dl_prec,dl_rec,dl_f1)

# %%
plt.plot(history1.history['loss'])
plt.plot(history1.history['val_loss'])

plt.plot(history1.history['accuracy'])
plt.plot(history1.history['val_accuracy'])

# %% [markdown]
# # CNN + LSTM

# %%
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X_res)

# Membagi data menjadi set pelatihan dan pengujian
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_res, test_size=0.4, random_state=42)

# %%
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, LSTM, Dense, Dropout, BatchNormalization, Reshape, GRU

# %%
def build_model(input_shape):
    model = Sequential()
    model.add(Conv1D(32, 1, activation='relu', input_shape=input_shape))
    model.add(BatchNormalization())
    model.add(MaxPooling1D(1))
    model.add(Dropout(0.1))
    model.add(Flatten())
    # Mengubah bentuk ke (batch_size, timesteps, features)
    model.add(Reshape((input_shape[0], 32)))
    model.add(LSTM(50, activation='tanh', return_sequences=False))
    model.add(Dropout(0.1))
    model.add(Dense(64, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01)))
    model.add(Dropout(0.1))
    model.add(Dense(1, activation='sigmoid'))
    return model

# %%
model7 = build_model((X_train.shape[1], 1))
model7.compile(loss='binary_crossentropy', metrics=['accuracy'])
model7.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_3 (Conv1D)           (None, 8, 32)             64
#
#  batch_normalization_3 (Batc  (None, 8, 32)            128
#  hNormalization)
#
#  max_pooling1d_3 (MaxPooling  (None, 8, 32)            0
#  1D)
#
#  dropout_8 (Dropout)         (None, 8, 32)             0
#
#  flatten_1 (Flatten)         (None, 256)               0
#
#  reshape (Reshape)           (None, 8, 32)             0
#
#  lstm_1 (LSTM)               (None, 50)                16600
#
#  dropout_9 (Dropout)         (None, 50)                0
#
#  dense_7 (Dense)             (None, 64)                3264
#
#  dropout_10 (Dropout)        (None, 64)                0
#
#  dense_8 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 20,121
# Trainable params: 20,057
# Non-trainable params: 64
# _________________________________________________________________

# %%
history7 = model7.fit(X_train, y_train, batch_size=2, validation_split=0.34,shuffle=True,epochs=30,verbose=1,callbacks=[callback])
# Out:
# Epoch 1/30
# 194/194 [==============================] - 4s 11ms/step - loss: 0.9122 - accuracy: 0.6211 - val_loss: 0.7405 - val_accuracy: 0.7114
# Epoch 2/30
# 194/194 [==============================] - 2s 9ms/step - loss: 0.6989 - accuracy: 0.6856 - val_loss: 0.6219 - val_accuracy: 0.7313
# Epoch 3/30
# 194/194 [==============================] - 2s 8ms/step - loss: 0.6656 - accuracy: 0.6624 - val_loss: 0.5748 - val_accuracy: 0.7313
# Epoch 4/30
# 194/194 [==============================] - 2s 9ms/step - loss: 0.6587 - accuracy: 0.6804 - val_loss: 0.5809 - val_accuracy: 0.7164
# Epoch 5/30
# 194/194 [==============================] - 2s 9ms/step - loss: 0.5942 - accuracy: 0.7139 - val_loss: 0.5841 - val_accuracy: 0.7562
# Epoch 6/30
# 194/194 [==============================] - 2s 9ms/step - loss: 0.6014 - accuracy: 0.7345 - val_loss: 0.6445 - val_accuracy: 0.7164
# Epoch 7/30
# 194/194 [==============================] - 2s 9ms/step - loss: 0.6176 - accuracy: 0.7062 - val_loss: 0.5751 - val_accuracy: 0.7363
# Epoch 8/30
# 194/194 [==============================] - 2s 9ms/step - loss: 0.5954 - accuracy: 0.6933 - val_loss: 0.5461 - val_accuracy: 0.7413
# Epoch 9/30
# 194/194 [==============================] - 2s 9ms/step - loss: 0.6119 - accuracy: 0.6959 - val_loss: 0.5454 - val_accuracy: 0.7214
# Epoch 10/30
# 194/194 [==============================] - 2s 9ms/step - loss: 0.6056 - accuracy: 0.7088 - val_loss: 0.5600 - val_accuracy: 0.7164

# %%
y_pred_prob = model7.predict(X_test)
y_pred4 = (y_pred_prob > 0.55).astype("int32")

dl_acc = accuracy_score(y_test,y_pred4)
dl_prec = precision_score(y_test,y_pred4)
dl_rec = recall_score(y_test,y_pred4)
dl_f1 = f1_score(y_test,y_pred4)
# Out:
# 13/13 [==============================] - 0s 2ms/step

# %%
storeResults('CNN+LSTM',dl_acc,dl_prec,dl_rec,dl_f1)

# %%
# Plotting akurasi
plt.plot(history7.history['accuracy'], label='Training Accuracy')
plt.plot(history7.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plotting kerugian
plt.plot(history7.history['loss'], label='Training Loss')
plt.plot(history7.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# # Stacking

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_res, test_size=0.4, random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.neural_network import MLPClassifier
from lightgbm import LGBMClassifier
from sklearn.ensemble import StackingClassifier

estimators = [('rf', RandomForestClassifier(n_estimators=10)),('mlp', MLPClassifier(random_state=1, max_iter=300))]

clf = StackingClassifier(estimators=estimators, final_estimator=LGBMClassifier())

# fit the model 
clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)
# Out:
# [LightGBM] [Info] Number of positive: 295, number of negative: 294
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000142 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 208
# [LightGBM] [Info] Number of data points in the train set: 589, number of used features: 2
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500849 -> initscore=0.003396
# [LightGBM] [Info] Start training from score 0.003396
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf

# %% [markdown]
# # Stack-LSTM

# %%
ml_acc = accuracy_score(y_pred,y_pred1)
ml_prec = precision_score(y_pred,y_pred1)
ml_rec = recall_score(y_pred,y_pred1)
ml_f1 = f1_score(y_pred,y_pred1)

storeResults('Stack-LSTM',ml_acc,ml_prec,ml_rec,ml_f1)

# %% [markdown]
# # Stack-ANN

# %%
ml_acc = accuracy_score(y_pred,y_pred2)
ml_prec = precision_score(y_pred,y_pred2)
ml_rec = recall_score(y_pred,y_pred2)
ml_f1 = f1_score(y_pred,y_pred2)

storeResults('Stack-ANN',ml_acc,ml_prec,ml_rec,ml_f1)

# %% [markdown]
# # Stack-CNN

# %%
ml_acc = accuracy_score(y_pred,y_pred3)
ml_prec = precision_score(y_pred,y_pred3)
ml_rec = recall_score(y_pred,y_pred3)
ml_f1 = f1_score(y_pred,y_pred3)

storeResults('Stack-CNN',ml_acc,ml_prec,ml_rec,ml_f1)

# %% [markdown]
# # Stack-CNN+LSTM

# %%
ml_acc = accuracy_score(y_pred,y_pred4)
ml_prec = precision_score(y_pred,y_pred4)
ml_rec = recall_score(y_pred,y_pred4)
ml_f1 = f1_score(y_pred,y_pred4)

storeResults('Stack-CNN+LSTM',ml_acc,ml_prec,ml_rec,ml_f1)

# %% [markdown]
# ML

# %%
X_train, X_test, y_train, y_test = train_test_split(X_res, y_res, test_size=0.4, random_state=42)

# %% [markdown]
# # SVC

# %%
from sklearn import svm
svc = svm.SVC(decision_function_shape='ovo',probability=True)
svc.fit(X_train, y_train)

y_pred    = svc.predict(X_test)

svc_acc = accuracy_score(y_pred, y_test)
svc_prec = precision_score(y_pred, y_test,average='weighted')
svc_rec = recall_score(y_pred, y_test,average='weighted')
svc_f1 = f1_score(y_pred, y_test,average='weighted')

# %%
storeResults('SVM',svc_acc,svc_prec,svc_rec,svc_f1)

# %% [markdown]
# # DecisionTree

# %%
from sklearn.tree import DecisionTreeClassifier

dt = DecisionTreeClassifier(criterion='entropy',max_features='log2',max_depth=25,min_samples_leaf=2,min_samples_split=5)

dt.fit(X_train, y_train)

y_pred = dt.predict(X_test)

dt_acc = accuracy_score(y_pred, y_test)
dt_prec = precision_score(y_pred, y_test,average='weighted')
dt_rec = recall_score(y_pred, y_test,average='weighted')
dt_f1 = f1_score(y_pred, y_test,average='weighted')

# %%
storeResults('DecisionTree',dt_acc,dt_prec,dt_rec,dt_f1)

# %% [markdown]
# # Extension

# %%
from sklearn.ensemble import VotingClassifier, BaggingClassifier, ExtraTreesClassifier, AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier()

bet = BaggingClassifier(ExtraTreesClassifier())

bdt = AdaBoostClassifier(
    DecisionTreeClassifier(max_depth=1), algorithm="SAMME", n_estimators=200
)

model = VotingClassifier(estimators= [('BoostDT', bdt),('RF', rf),('BagET', bet)], voting='soft')

model.fit(X_train, y_train)

y_pred = model.predict(X_test)

ext_acc = accuracy_score(y_pred, y_test)
ext_prec = precision_score(y_pred, y_test,average='weighted')
ext_rec = recall_score(y_pred, y_test,average='weighted')
ext_f1 = f1_score(y_pred, y_test,average='weighted')

# %%
storeResults('Extension',ext_acc,ext_prec,ext_rec,ext_f1)

# %% [markdown]
# # Comparison

# %%
#creating dataframe
result = pd.DataFrame({ 'ML Model' : ML_Model,
                        'Accuracy' : accuracy,
                       'Precision': precision,
                       'Recall'   : recall, 
                       'F1_score' : f1score 
                      })

# %%
result
# Out:
#           ML Model  Accuracy  Precision  Recall  F1_score
# 0             LSTM     0.758      0.762   0.750     0.756
# 1              ANN     0.501      0.000   0.000     0.000
# 2              CNN     0.578      0.578   0.566     0.572
# 3         CNN+LSTM     0.733      0.763   0.673     0.715
# 4       Stack-LSTM     0.804      0.855   0.771     0.811
# 5        Stack-ANN     0.455      0.000   0.000     0.000
# 6        Stack-CNN     0.679      0.729   0.654     0.690
# 7   Stack-CNN+LSTM     0.768      0.855   0.692     0.765
# 8              SVM     0.728      0.730   0.728     0.728
# 9     DecisionTree     0.728      0.728   0.728     0.728
# 10       Extension     0.819      0.821   0.819     0.820

# %% [markdown]
# # Modelling

# %%
import joblib
filename = 'model_data2.sav'
joblib.dump(model, filename)
# Out:
# ['model_data2.sav']

# %% [markdown]
# # Graph

# %%
classifier = ML_Model
y_pos = np.arange(len(classifier))

# %% [markdown]
# # Accuracy

# %%
import matplotlib.pyplot as plt2
plt2.barh(y_pos, accuracy, align='center', alpha=0.5,color='blue')
plt2.yticks(y_pos, classifier)
plt2.xlabel('Accuracy Score')
plt2.title('Classification Performance')
plt2.show()

# %% [markdown]
# # Precision

# %%
plt2.barh(y_pos, precision, align='center', alpha=0.5,color='red')
plt2.yticks(y_pos, classifier)
plt2.xlabel('Precision Score')
plt2.title('Classification Performance')
plt2.show()

# %% [markdown]
# # Recall

# %%
plt2.barh(y_pos, recall, align='center', alpha=0.5,color='yellow')
plt2.yticks(y_pos, classifier)
plt2.xlabel('Recall Score')
plt2.title('Classification Performance')
plt2.show()

# %% [markdown]
# # F1 Score

# %%
plt2.barh(y_pos, f1score, align='center', alpha=0.5,color='navy')
plt2.yticks(y_pos, classifier)
plt2.xlabel('F1 Score')
plt2.title('Classification Performance')
plt2.show()
